# %% [markdown]
# # Cleaning item-specific data

# %%
import pandas as pd
from sqlalchemy import create_engine
import sys
sys.path.append('../DB_access')
import credentials as cred


driver = cred.driver()
user = cred.user()
password = cred.password()
ip = cred.ip()
database = cred.database()

connection_string = f'{driver}//{user}:{password}@{ip}/{database}'
engine = create_engine(connection_string)

# %%
items = pd.read_sql('items', con = engine)

# %%
items.head()
# Out:
#    index   Name  Lineitem quantity                            Lineitem name  \
# 0      0  #1248                  4          Plátano Canarias - 3/4 unidades
# 1      1  #1248                  2       Fresón Maresme - 1 caja (500 grs.)
# 2      2  #1248                  1                  Tomate Cherry - 200 grs
# 3      3  #1248                  1  Nueces California sin cáscara - 200 grs
# 4      4  #1248                  3                Mandarina Orri - 500 grs.
#
#    Lineitem price Lineitem fulfillment status Cancelled at  Refunded Amount  \
# 0            1.95                   fulfilled         None              0.0
# 1            3.50                   fulfilled         None              NaN
# 2            1.30                   fulfilled         None              NaN
# 3            3.44                   fulfilled         None              NaN
# 4            2.00                   fulfilled         None              NaN
#
#                       Vendor  Tags  Lineitem discount
# 0  Fruites i Verdures Rovira  None                  0
# 1  Fruites i Verdures Rovira  None                  0
# 2  Fruites i Verdures Rovira  None                  0
# 3        Llegums Porta Novau  None                  0
# 4  Fruites i Verdures Rovira  None                  0

# %% [markdown]
# We'll drop the index column as it is redundant and the 'id' (which corresponds to the order and it's redundant with 'Name'

# %%
items = items.drop(columns='index')

# %%
items.head()
# Out:
#     Name  Lineitem quantity                            Lineitem name  \
# 0  #1248                  4          Plátano Canarias - 3/4 unidades
# 1  #1248                  2       Fresón Maresme - 1 caja (500 grs.)
# 2  #1248                  1                  Tomate Cherry - 200 grs
# 3  #1248                  1  Nueces California sin cáscara - 200 grs
# 4  #1248                  3                Mandarina Orri - 500 grs.
#
#    Lineitem price Lineitem fulfillment status Cancelled at  Refunded Amount  \
# 0            1.95                   fulfilled         None              0.0
# 1            3.50                   fulfilled         None              NaN
# 2            1.30                   fulfilled         None              NaN
# 3            3.44                   fulfilled         None              NaN
# 4            2.00                   fulfilled         None              NaN
#
#                       Vendor  Tags  Lineitem discount
# 0  Fruites i Verdures Rovira  None                  0
# 1  Fruites i Verdures Rovira  None                  0
# 2  Fruites i Verdures Rovira  None                  0
# 3        Llegums Porta Novau  None                  0
# 4  Fruites i Verdures Rovira  None                  0

# %% [markdown]
# ## NaN values

# %%
items.isna().sum()
# Out:
# Name                              0
# Lineitem quantity                 0
# Lineitem name                     0
# Lineitem price                    0
# Lineitem fulfillment status       0
# Cancelled at                   3052
# Refunded Amount                2874
# Vendor                            1
# Tags                           3094
# Lineitem discount                 0
# dtype: int64

# %%
items.shape
# Out:
# (3120, 10)

# %% [markdown]
# We will drop 'Tags' as it does not provide any information

# %%
items = items.drop(columns='Tags')

# %% [markdown]
# We will fill the empty refunded amounts with 0. And Cancelled at with 'not cancelled'

# %%
items['Cancelled at'] =items['Cancelled at'].fillna('not cancelled')

# %%
items['Refunded Amount'] =items['Refunded Amount'].fillna(0)

# %% [markdown]
# There is only one Nan value in vendor. We check what's going on.

# %%
items[items['Vendor'].isna()]
# Out:
#       Name  Lineitem quantity               Lineitem name  Lineitem price  \
# 976  #1201                  1  Pechuga de pollo fileteada            3.15
#
#     Lineitem fulfillment status   Cancelled at  Refunded Amount Vendor  \
# 976                   fulfilled  not cancelled              0.0   None
#
#      Lineitem discount
# 976                  0

# %%
items[items['Lineitem name'].map(lambda x: 'pollo' in x)]
# Out:
#        Name  Lineitem quantity  \
# 24    #1247                  1
# 48    #1246                  1
# 69    #1245                  1
# 95    #1244                  1
# 141   #1240                  1
# 182   #1239                  1
# 197   #1238                  1
# 220   #1237                  1
# 238   #1236                  1
# 255   #1235                  1
# 276   #1235                  1
# 308   #1234                  1
# 318   #1233                  1
# 339   #1233                  1
# 353   #1232                  1
# 373   #1231                  1
# 405   #1229                  1
# 420   #1227                  1
# 433   #1227                  2
# 459   #1226                  1
# 465   #1226                  1
# 479   #1225                  1
# 512   #1222                  1
# 552   #1220                  1
# 565   #1220                  2
# 650   #1216                  1
# 694   #1215                  1
# 738   #1212                  1
# 749   #1212                  1
# 750   #1212                  1
# ...     ...                ...
# 2733  #1057                  1
# 2751  #1056                  1
# 2754  #1055                  2
# 2791  #1052                  1
# 2792  #1052                  1
# 2804  #1050                  1
# 2839  #1049                  2
# 2840  #1049                  3
# 2845  #1048                  2
# 2846  #1048                  1
# 2854  #1047                  1
# 2855  #1047                  1
# 2867  #1045                  1
# 2868  #1045                  1
# 2884  #1044                  1
# 2885  #1044                  1
# 2909  #1040                  2
# 2910  #1040                  3
# 2913  #1038                  1
# 2932  #1034                  2
# 2933  #1034                  1
# 2948  #1032                  1
# 2949  #1032                  1
# 2950  #1032                  1
# 2968  #1028                  1
# 3034  #1020                  2
# 3052  #1019                  1
# 3069  #1012                  1
# 3071  #1012                  1
# 3100  #1009                  1
#
#                                           Lineitem name  Lineitem price  \
# 24                Pechuga de pollo fileteada (350 grs.)            3.15
# 48      Hamburguesas Gourmet de pollo lisa - 3 unidades            4.80
# 69    Brochetas de pechuga de pollo a las finas hier...            4.40
# 95                Pechuga de pollo fileteada (350 grs.)            3.15
# 141               Pechuga de pollo fileteada (350 grs.)            3.15
# 182               Pechuga de pollo fileteada (350 grs.)            3.15
# 197               Pechuga de pollo fileteada (350 grs.)            3.15
# 220               Pechuga de pollo fileteada (350 grs.)            3.15
# 238               Pechuga de pollo fileteada (350 grs.)            3.15
# 255               Pechuga de pollo fileteada (350 grs.)            3.15
# 276     Hamburguesas Gourmet de pollo lisa - 3 unidades            4.80
# 308               Pechuga de pollo fileteada (350 grs.)            3.15
# 318               Pechuga de pollo fileteada (350 grs.)            3.15
# 339     Hamburguesas Gourmet de pollo lisa - 3 unidades            4.80
# 353               Pechuga de pollo fileteada (350 grs.)            3.15
# 373               Pechuga de pollo fileteada (350 grs.)            3.15
# 405               Pechuga de pollo fileteada (350 grs.)            3.15
# 420               Pechuga de pollo fileteada (350 grs.)            3.15
# 433     Hamburguesas Gourmet de pollo lisa - 2 unidades            3.20
# 459               Pechuga de pollo fileteada (350 grs.)            3.15
# 465     Hamburguesas Gourmet de pollo lisa - 2 unidades            3.20
# 479               Pechuga de pollo fileteada (350 grs.)            3.15
# 512               Pechuga de pollo fileteada (350 grs.)            3.15
# 552               Pechuga de pollo fileteada (350 grs.)            3.15
# 565     Hamburguesas Gourmet de pollo lisa - 2 unidades            3.20
# 650               Pechuga de pollo fileteada (350 grs.)            3.15
# 694               Pechuga de pollo fileteada (350 grs.)            3.15
# 738                  Alitas de pollo enteras - 650 grs.            2.60
# 749               Pechuga de pollo fileteada (350 grs.)            3.15
# 750     Hamburguesas Gourmet de pollo lisa - 2 unidades            3.20
# ...                                                 ...             ...
# 2733       Pechuga pollo fileteada - 1 pechuga (300 gr)            3.00
# 2751       Pechuga pollo fileteada - 1 pechuga (300 gr)            3.00
# 2754       Pechuga pollo fileteada - 1 pechuga (300 gr)            3.00
# 2791                   Croquetas de pollo - 10 unidades            3.50
# 2792       Pechuga pollo fileteada - 1 pechuga (300 gr)            3.00
# 2804       Pechuga pollo fileteada - 1 pechuga (300 gr)            3.00
# 2839                 Muslos de pollo - 4 unidades (1kg)            6.90
# 2840       Pechuga pollo fileteada - 1 pechuga (300 gr)            3.00
# 2845                   Croquetas de pollo - 10 unidades            3.50
# 2846       Pechuga pollo fileteada - 1 pechuga (300 gr)            3.00
# 2854                   Croquetas de pollo - 10 unidades            3.50
# 2855       Pechuga pollo fileteada - 1 pechuga (300 gr)            3.00
# 2867                 Muslos de pollo - 4 unidades (1kg)            6.90
# 2868                 Hamburguesas de pollo - 2 unidades            2.20
# 2884                   Croquetas de pollo - 10 unidades            3.50
# 2885       Pechuga pollo fileteada - 1 pechuga (300 gr)            3.00
# 2909                  Medio pollo a octavos - 1/2 pollo            4.00
# 2910                   Croquetas de pollo - 10 unidades            3.50
# 2913                  Medio pollo a octavos - 1/2 pollo            4.00
# 2932                 Muslos de pollo - 4 unidades (1kg)            6.90
# 2933                 Hamburguesas de pollo - 2 unidades            2.20
# 2948                  Medio pollo a cuartos - 1/2 pollo            4.00
# 2949                  Medio pollo a octavos - 1/2 pollo            4.00
# 2950            Hamburguesas pollo/cebolla - 2 unidades            2.40
# 2968              Hamburguesas pollo/queso - 2 unidades            2.40
# 3034       Pechuga pollo fileteada - 1 pechuga (300 gr)            3.00
# 3052       Pechuga pollo fileteada - 1 pechuga (300 gr)            3.00
# 3069                   Croquetas de pollo - 10 unidades            3.50
# 3071       Pechuga pollo fileteada - 1 pechuga (300 gr)            4.95
# 3100                   Croquetas de pollo - 10 unidades            3.50
#
#      Lineitem fulfillment status   Cancelled at  Refunded Amount  \
# 24                     fulfilled  not cancelled              0.0
# 48                     fulfilled  not cancelled              0.0
# 69                     fulfilled  not cancelled              0.0
# 95                     fulfilled  not cancelled              0.0
# 141                    fulfilled  not cancelled              0.0
# 182                    fulfilled  not cancelled              0.0
# 197                    fulfilled  not cancelled              0.0
# 220                    fulfilled  not cancelled              0.0
# 238                    fulfilled  not cancelled              0.0
# 255                    fulfilled  not cancelled              0.0
# 276                    fulfilled  not cancelled              0.0
# 308                    fulfilled  not cancelled              0.0
# 318                    fulfilled  not cancelled              0.0
# 339                    fulfilled  not cancelled              0.0
# 353                    fulfilled  not cancelled              0.0
# 373                    fulfilled  not cancelled              0.0
# 405                    fulfilled  not cancelled              0.0
# 420                    fulfilled  not cancelled              0.0
# 433                    fulfilled  not cancelled              0.0
# 459                    fulfilled  not cancelled              0.0
# 465                    fulfilled  not cancelled              0.0
# 479                    fulfilled  not cancelled              0.0
# 512                    fulfilled  not cancelled              0.0
# 552                    fulfilled  not cancelled              0.0
# 565                    fulfilled  not cancelled              0.0
# 650                    fulfilled  not cancelled              0.0
# 694                    fulfilled  not cancelled              0.0
# 738                    fulfilled  not cancelled              0.0
# 749                    fulfilled  not cancelled              0.0
# 750                    fulfilled  not cancelled              0.0
# ...                          ...            ...              ...
# 2733                   fulfilled  not cancelled              0.0
# 2751                   fulfilled  not cancelled              0.0
# 2754                   fulfilled  not cancelled              0.0
# 2791                   fulfilled  not cancelled              0.0
# 2792                   fulfilled  not cancelled              0.0
# 2804                   fulfilled  not cancelled              0.0
# 2839                   fulfilled  not cancelled              0.0
# 2840                   fulfilled  not cancelled              0.0
# 2845                   fulfilled  not cancelled              0.0
# 2846                   fulfilled  not cancelled              0.0
# 2854                   fulfilled  not cancelled              0.0
# 2855                   fulfilled  not cancelled              0.0
# 2867                     pending  not cancelled              0.0
# 2868                     pending  not cancelled              0.0
# 2884                     pending  not cancelled              0.0
# 2885                     pending  not cancelled              0.0
# 2909                     pending  not cancelled              0.0
# 2910                     pending  not cancelled              0.0
# 2913                     pending  not cancelled              0.0
# 2932                     pending  not cancelled              0.0
# 2933                     pending  not cancelled              0.0
# 2948                     pending  not cancelled              0.0
# 2949                     pending  not cancelled              0.0
# 2950                     pending  not cancelled              0.0
# 2968                     pending  not cancelled              0.0
# 3034                   fulfilled  not cancelled              0.0
# 3052                     pending  not cancelled              0.0
# 3069                   fulfilled  not cancelled              0.0
# 3071                   fulfilled  not cancelled              0.0
# 3100                     pending  not cancelled              0.0
#
#              Vendor  Lineitem discount
# 24         El Pagés                  0
# 48         El Pagés                  0
# 69         El Pagés                  0
# 95         El Pagés                  0
# 141        El Pagés                  0
# 182        El Pagés                  0
# 197        El Pagés                  0
# 220        El Pagés                  0
# 238        El Pagés                  0
# 255        El Pagés                  0
# 276        El Pagés                  0
# 308        El Pagés                  0
# 318        El Pagés                  0
# 339        El Pagés                  0
# 353        El Pagés                  0
# 373        El Pagés                  0
# 405        El Pagés                  0
# 420        El Pagés                  0
# 433        El Pagés                  0
# 459        El Pagés                  0
# 465        El Pagés                  0
# 479        El Pagés                  0
# 512        El Pagés                  0
# 552        El Pagés                  0
# 565        El Pagés                  0
# 650        El Pagés                  0
# 694        El Pagés                  0
# 738        El Pagés                  0
# 749        El Pagés                  0
# 750        El Pagés                  0
# ...             ...                ...
# 2733  Aviram Mónica                  0
# 2751  Aviram Mónica                  0
# 2754  Aviram Mónica                  0
# 2791  Aviram Mónica                  0
# 2792  Aviram Mónica                  0
# 2804  Aviram Mónica                  0
# 2839  Aviram Mónica                  0
# 2840  Aviram Mónica                  0
# 2845  Aviram Mónica                  0
# 2846  Aviram Mónica                  0
# 2854  Aviram Mónica                  0
# 2855  Aviram Mónica                  0
# 2867  Aviram Mónica                  0
# 2868  Aviram Mónica                  0
# 2884  Aviram Mónica                  0
# 2885  Aviram Mónica                  0
# 2909  Aviram Mónica                  0
# 2910  Aviram Mónica                  0
# 2913  Aviram Mónica                  0
# 2932  Aviram Mónica                  0
# 2933  Aviram Mónica                  0
# 2948  Aviram Mónica                  0
# 2949  Aviram Mónica                  0
# 2950  Aviram Mónica                  0
# 2968  Aviram Mónica                  0
# 3034  Aviram Mónica                  0
# 3052  Aviram Mónica                  0
# 3069  Aviram Mónica                  0
# 3071  Aviram Mónica                  0
# 3100  Aviram Mónica                  0
#
# [157 rows x 9 columns]

# %% [markdown]
# We can see that the usual vendor for this type of items is 'El Pagés' therefore, we will fill the Nan with this value

# %%
items['Vendor'] = items['Vendor'].fillna('El Pagés')

# %% [markdown]
# ## Variable types

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3120 entries, 0 to 3119
# Data columns (total 9 columns):
# Name                           3120 non-null object
# Lineitem quantity              3120 non-null int64
# Lineitem name                  3120 non-null object
# Lineitem price                 3120 non-null float64
# Lineitem fulfillment status    3120 non-null object
# Cancelled at                   3120 non-null object
# Refunded Amount                3120 non-null float64
# Vendor                         3120 non-null object
# Lineitem discount              3120 non-null int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 219.5+ KB

# %% [markdown]
# Types seem ok

# %% [markdown]
# ## Feature values

# %%
items.columns
# Out:
# Index(['Name', 'Lineitem quantity', 'Lineitem name', 'Lineitem price',
#        'Lineitem fulfillment status', 'Cancelled at', 'Refunded Amount',
#        'Vendor', 'Lineitem discount'],
#       dtype='object')

# %% [markdown]
# #### Quantity -- OK

# %%
items['Lineitem quantity'].value_counts()
# Out:
# 1     2793
# 2      250
# 3       40
# 4       22
# 6        4
# 10       3
# 16       2
# 12       2
# 8        2
# 5        1
# 30       1
# Name: Lineitem quantity, dtype: int64

# %% [markdown]
# Looks good

# %% [markdown]
# #### Lineitem name'

# %%
items['Lineitem name'].value_counts()
# Out:
# Huevos - 1/2 docena                                         41
# Brócoli - 1 unidad                                          40
# Pechuga pollo fileteada - 1 pechuga (300 gr)                39
# Pera Conference - 4 unidades                                39
# Plátano Canarias Verde - 3/4 unidades                       38
# Lote de productos básicos - Donativo Banc d'Aliments        38
# Zanahorias - medio kilo                                     36
# Plátano canario (verde) - 0.5 kg. (3-4 unidades)            35
# Huevos ecológicos (6 unidades)                              33
# Almendra Cruda - 125 grs.                                   33
# Manzana Golden - 4 unidades                                 33
# Nueces California sin cáscara - 125 grs.                    32
# Calabacín - 500 grs.                                        29
# Tomate Monterosa - 500 grs.                                 28
# Cebolla Reca para guisar (1 Kg. = 3/4 uds.)                 27
# Calabacines - 500 grs. (2-3 unidades)                       26
# Kiwi Green - 4 unidades                                     25
# Fresón Maresme - 1 caja (500 grs.)                          25
# Pechuga de pollo fileteada (350 grs.)                       25
# Garbanzo cocido - 1 ración (250 grs.)                       24
# Aguacate - 1 unidad                                         23
# Puerros - 3 unidades                                        22
# Espinacas - Bolsa 300 grs.                                  22
# Patata Monalisa (hervir) - 1 kg.                            22
# Cebolla de Figueras - 1 kg                                  21
# Lechuga francesa - 1 unidad                                 21
# Garbanzos cocidos - 500 grs.                                21
# Lenteja cocida Pequeña (pardina) - 350 grs,                 18
# Berenjenas - 0.6 kg. (2-3 unidades)                         18
# Naranja valenciana - 1 kg. aprox. 4 uds.                    17
#                                                             ..
# Merluza limpia (suprema pequeña) - 500 grs. (2 raciones)     1
# Almendra Tostada - 500 grs.                                  1
# Montgeta genoll de Crist - 1 ración (250 grs.)               1
# Ciruelas con hueso - 250 grs.                                1
# Caprice de Dieux - 1 unidad                                  1
# Avellana Cruda - 500 grs.                                    1
# Hamburg. sobrasada/queso - 2 unidades                        1
# Cesta de Temporada   (1/2 pensión) - 2                       1
# Lenteja cocida (pedido especial) - 1 Kg.                     1
# Azuqui - 1 ración (250 grs.)                                 1
# Filetes de Dorada - 2 unidades                               1
# Hummus (pedido especial) - 1 Kg.                             1
# Yogures (4 unidades)                                         1
# Zanahoria Granel - 150 grs.                                  1
# Endivias - 3 unidades                                        1
# Macadamia cruda - 100 gramos                                 1
# Pechuga fileteada - 300 gramos                               1
# Producto Personalizado Porta Novau                           1
# Esparragos verdes puntas - 1 manojo (225 grs.)               1
# Mero en rodajas - 2 raciones                                 1
# Sepia Limpia - unidad                                        1
# Fuet con pimienta - 1 pieza                                  1
# Jamón ibérico - 150 grs.                                     1
# Caldo - 1 litro                                              1
# Tomate Raf - 1 unidad                                        1
# Tomate Barbastro - 1 Kg. (3-4 unidades)                      1
# Almendra Cruda - 250 grs.                                    1
# Lenguado limpio - 2 raciones                                 1
# Croquetas de jamón - 3 unidades                              1
# Tall Rodó bacon/dátiles - 1 unidad (1kg)                     1
# Name: Lineitem name, Length: 536, dtype: int64

# %% [markdown]
# After analysing all the patterns we could find, we simplify the description of each item and create a tag list. Below, there's an example of the serch for patterns. We will search for 'pollo' and then the other registers will be changed to others as there is no item 'fruta'

# %%
items['Lineitem name'][items['Lineitem name'].map(lambda x: x.startswith('Brocheta'))]
# Out:
# 69      Brochetas de pechuga de pollo a las finas hier...
# 998     Brochetas de pechuga de pollo barbacoa - 5 uni...
# 1010    Brochetas de pechuga de pollo barbacoa - 5 uni...
# 2519                       Brocheta de fruta - 3 unidades
# Name: Lineitem name, dtype: object

# %%
items['Lineitem name'][items['Lineitem name'].map(lambda x: x.startswith('Virutas'))]
# Out:
# 1043    Virutas de Jamón de bellota - 150 grs.
# Name: Lineitem name, dtype: object

# %% [markdown]
# This contains too much information, we will split the content and create tags. The rest of information will go in 'Notes'.

# %%
# We will reduce the information contained in the item description by creating a tag with the main food item.

# Create a list with all the items but reducing the ones with 'pollo' and 'pavo' as they are quite recurent and varied
mylst = list(items['Lineitem name'].map(lambda x: 'Pollo' if x.find('pollo') > 0 else ('Pavo' if x.find('pavo') > 0 else x)))

# We now take the fist word of the list as it will describe the main food item for 95% of the items.
tags = []
for tag in mylst:
    tags.append(tag.split(' ')[0])

# Now we solve the special cases
for index, tag in enumerate(tags):
    if tag == 'Cabezas':
        tags[index] = 'Ajo'
    elif tag == 'Cabeza':
        tags[index] = 'Ajo'        
    elif tag == 'Rulo':
        tags[index] = 'Queso'
    elif tag == 'Hamburguesa':
        tags[index] = 'Ternera'
    elif tag == 'Manchego':
        tags[index] = 'Queso'
    elif tag == 'Medio':
        tags[index] = 'Conejo'
    elif tag == 'Brie':
        tags[index] = 'Queso'
    elif tag == 'Emmental':
        tags[index] = 'Queso'
    elif tag == 'Cammenbert':
        tags[index] = 'Queso'
    elif tag == 'Comté':
        tags[index] = 'Queso'
    elif tag == 'Colitas':
        tags[index] = 'Rape'
    elif tag == 'Copos':
        tags[index] = 'Avena'
    elif tag == 'Tapa':
        tags[index] = 'Ternera'
    elif tag == 'Producto':
        tags[index] = 'Others'
    elif tag == 'Picos':
        tags[index] = 'Pan'
    elif tag == 'Tostaditas':
        tags[index] = 'Pan'
    elif tag == 'Barra':
        tags[index] = 'Pan'
    elif tag == '1':
        tags[index] = 'Pan'
    elif tag == 'Alcachofas':
        tags[index] = 'Alcachofa'
    elif tag == 'Azuqui':
        tags[index] = 'Azuki'
    elif tag == 'Baguet':
        tags[index] = 'Pan'
    elif tag == 'Berenjenas':
        tags[index] = 'Berenjena'
    elif tag == 'Broquil':
        tags[index] = 'Brócoli'
    elif tag == 'Calabacines':
        tags[index] = 'Calabacín'
    elif tag == 'Calamares':
        tags[index] = 'Calamar'
    elif tag == 'Ciruelas':
        tags[index] = 'Ciruela'
    elif tag == 'Codornices':
        tags[index] = 'Codorniz'
    elif tag == 'Coles':
        tags[index] = 'Col'
    elif tag == 'Conill':
        tags[index] = 'Conejo'
    elif tag == 'Cous':
        tags[index] = 'Cous-cous'
    elif tag == 'Esparragos':
        tags[index] = 'Esparrago'
    elif tag == 'Feta':
        tags[index] = 'Queso'
    elif tag == 'Filetes':
        tags[index] = 'Filet'
    elif tag == 'Fresones':
        tags[index] = 'Fresón'
    elif tag == 'Garbanzos':
        tags[index] = 'Garbanzo'
    elif tag == 'Idiazábal':
        tags[index] = 'Queso'
    elif tag == 'Judías':
        tags[index] = 'Judía'
    elif tag == 'Lentejas':
        tags[index] = 'Lenteja'
    elif tag == 'Libritos':
        tags[index] = 'Librito'
    elif tag == 'Manzanas':
        tags[index] = 'Manzana'
    elif tag == 'Mejillones':
        tags[index] = 'Mejillón'
    elif tag == 'Naranjas':
        tags[index] = 'Naranja'
    elif tag == 'Nueces':
        tags[index] = 'Nuez'
    elif tag == 'Pasas':
        tags[index] = 'Pasa'
    elif tag == 'Pimientos':
        tags[index] = 'Pimiento'
    elif tag == 'Puerros':
        tags[index] = 'Puerro'
    elif tag == 'Salmon':
        tags[index] = 'Salmón'
    elif tag == 'Tapaplana':
        tags[index] = 'Ternera'
    elif tag == 'Tomates':
        tags[index] = 'Tomate'
    elif tag == 'Zanahorias':
        tags[index] = 'Zanahoria'
    elif tag == 'Boloñesa':
        tags[index] = 'Macarrones'
    elif tag == 'Brocheta':
        tags[index] = 'Others'
    elif tag == 'Cabra':
        tags[index] = 'Queso'
    elif tag == 'Caprice':
        tags[index] = 'Queso'
    elif tag == 'Carne':
        tags[index] = 'Ternera'
    elif tag == 'Cola':
        tags[index] = 'Rape'
    elif tag == 'Fiambre':
        tags[index] = 'Pavo'
    elif tag == 'Flores':
        tags[index] = 'Queso'
    elif tag == 'Hamburg.':
        tags[index] = 'Others'
    elif tag == 'Hamburguesas':
        tags[index] = 'Ternera'
    elif tag == 'Lomo':
        tags[index] = 'Cerdo'
    elif tag == 'Lomos':
        tags[index] = 'Conejo'
    elif tag == 'Mediana':
        tags[index] = 'Conejo'
    elif tag == 'Mini-hamburguesas':
        tags[index] = 'Ternera'
    elif tag == 'Mini-harmburguesas':
        tags[index] = 'Ternera'
    elif tag == 'Zanahorias':
        tags[index] = 'Zanahoria'
    elif tag == 'Muslitos':
        tags[index] = 'Pollo'
    elif tag == 'Muslos':
        tags[index] = 'Pollo'
    elif tag == 'Oveja':
        tags[index] = 'Queso'
    elif tag == 'Pechuga':
        tags[index] = 'Pollo'
    elif tag == 'Pechugas':
        tags[index] = 'Pollo'
    elif tag == 'Tacos':
        tags[index] = 'Cerdo'
    elif tag == 'Tall':
        tags[index] = 'Ternera'
    elif tag == 'Bandeja':
        tags[index] = 'Pollo'
    elif tag == 'Chuleta':
        tags[index] = 'Ternera'
    elif tag == 'Culata':
        tags[index] = 'Ternera'
    elif tag == 'Espalda':
        tags[index] = 'Conejo'
    elif tag == 'Lote':
        tags[index] = 'Others'
    elif tag == 'Mitjana':
        tags[index] = 'Ternera'
    elif tag == 'Pepinos':
        tags[index] = 'Pepino'
    elif tag == 'Virutas':
        tags[index] = 'Jamón'
    elif tag == 'Ajos':
        tags[index] = 'Ajo'
    else:
        pass

# %%
items['tags'] = tags

# %%
sorted(items['tags'].unique())
# Out:
# ['Aceite',
#  'Acelgas',
#  'Agua',
#  'Aguacate',
#  'Ajo',
#  'Albaricoque',
#  'Albóndigas',
#  'Alcachofa',
#  'Almejas',
#  'Almendra',
#  'Alubia',
#  'Anacardo',
#  'Apio',
#  'Arroz',
#  'Arándanos',
#  'Atun',
#  'Avellana',
#  'Avena',
#  'Azuki',
#  'Bananas',
#  'Berberechos',
#  'Berenjena',
#  'Bonito',
#  'Boquerones',
#  'Brócoli',
#  'Bull',
#  'Butifarra',
#  'Caballa',
#  'Cacahuetes',
#  'Calabacín',
#  'Calabaza',
#  'Calamar',
#  'Caldo',
#  'Calçots',
#  'Canelones',
#  'Canónigos',
#  'Cebolla',
#  'Cep',
#  'Cerdo',
#  'Cerezas',
#  'Cesta',
#  'Champiñón',
#  'Chirimoya',
#  'Chocolate',
#  'Chorizo',
#  'Ciruela',
#  'Codorniz',
#  'Cogollos',
#  'Col',
#  'Coliflor',
#  'Conejo',
#  'Confit',
#  'Costillas',
#  'Cous-cous',
#  'Croquetas',
#  'Dorada',
#  'Dátiles',
#  'Endivias',
#  'Eneldo',
#  'Ensalada',
#  'Entrecot',
#  'Escarola',
#  'Espaguetis',
#  'Esparrago',
#  'Espectec',
#  'Espinacas',
#  'Filet',
#  'Frambuesas',
#  'Fresón',
#  'Frijoles',
#  'Fuet',
#  'Gamba',
#  'Garbanzo',
#  'Girgola',
#  'Granada',
#  'Granola',
#  'Higos',
#  'Huevos',
#  'Hummus',
#  'Jamón',
#  'Judía',
#  'Kakis',
#  'Kiwi',
#  'Lasagna',
#  'Lechuga',
#  'Lenguado',
#  'Lenteja',
#  'Librito',
#  'Limón',
#  'Lubina',
#  'Macadamia',
#  'Macarrones',
#  'Magret',
#  'Mandarina',
#  'Mango',
#  'Manzana',
#  'Mejillón',
#  'Melocotón',
#  'Melón',
#  'Merluza',
#  'Mero',
#  'Mijo',
#  'Montgeta',
#  'Mortadela',
#  'Naranja',
#  'Nectarina',
#  'Nuez',
#  'Obleas',
#  'Orejones',
#  'Others',
#  'Pan',
#  'Paraguayo',
#  'Pasa',
#  'Pasta',
#  'Patata',
#  'Pavo',
#  'Pepino',
#  'Pera',
#  'Pescadilla',
#  'Picantón',
#  'Pimiento',
#  'Pistacho',
#  'Piña',
#  'Plátano',
#  'Pollo',
#  'Pomelo',
#  'Puerro',
#  'Queso',
#  'Quinoa',
#  'Rape',
#  'Revuelto',
#  'Rossinyol',
#  'Rúcula',
#  'Salchichas',
#  'Salmonetes',
#  'Salmón',
#  'Salsa',
#  'Sandía',
#  'Sardina',
#  'Sepia',
#  'Shiitake',
#  'Sobrasada',
#  'Soja',
#  'Solomillo',
#  'Spaghetti',
#  'Sumaia',
#  'Ternera',
#  'Tomate',
#  'Tortilla',
#  'Uva',
#  'Vaca',
#  'Yogures',
#  'Zanahoria',
#  'salchichón']

# %% [markdown]
# #### 'Lineitem price' --OK

# %% [markdown]
# Looks good

# %% [markdown]
# #### 'Lineitem fulfillment status' -- OK

# %%
items['Lineitem fulfillment status'].value_counts()
# Out:
# fulfilled    2872
# pending       248
# Name: Lineitem fulfillment status, dtype: int64

# %% [markdown]
# # Load data

# %%
items.to_sql('items', con = engine, if_exists='replace')
