# %% [markdown]
# # Data exploration and cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data loading and exploration

# %%
orders = pd.read_csv('../00.Data/orders_cripted.csv')

# %%
orders.head()
# Out:
#     Name Financial Status                    Paid at Fulfillment Status  \
# 0  #1244             paid  2019-04-15 09:51:49 +0200        unfulfilled
# 1  #1243             paid  2019-04-11 23:35:23 +0200          fulfilled
# 2  #1243              NaN                        NaN                NaN
# 3  #1242         refunded  2019-04-11 23:21:35 +0200        unfulfilled
# 4  #1242              NaN                        NaN                NaN
#
#                 Fulfilled at Accepts Marketing Currency  Subtotal  Shipping  \
# 0                        NaN               yes      EUR      45.0       4.9
# 1  2019-04-11 23:43:20 +0200               yes      EUR      40.1       4.9
# 2                        NaN               NaN      NaN       NaN       NaN
# 3                        NaN               yes      EUR      40.1       4.9
# 4                        NaN               NaN      NaN       NaN       NaN
#
#    Taxes  Total Discount Code  Discount Amount Shipping Method  \
# 0    0.0   49.9           NaN              0.0  Envío estándar
# 1    0.0   45.0           NaN              0.0  Envío estándar
# 2    NaN    NaN           NaN              NaN             NaN
# 3    0.0   45.0           NaN              0.0  Envío estándar
# 4    NaN    NaN           NaN              NaN             NaN
#
#                   Created at  Lineitem quantity  \
# 0  2019-04-15 09:51:49 +0200                  1
# 1  2019-04-11 23:35:23 +0200                  2
# 2  2019-04-11 23:35:23 +0200                  1
# 3  2019-04-11 23:21:34 +0200                  2
# 4  2019-04-11 23:21:34 +0200                  1
#
#                                       Lineitem name  Lineitem price  \
# 0  Cesta de temporada sin pescado (1/2 pensión) - 2            45.0
# 1     Hamburguesa de cebolla queso y huevo (2 uds.)             3.8
# 2                                 TEM - QA - 17 - 2            32.5
# 3     Hamburguesa de cebolla queso y huevo (2 uds.)             3.8
# 4                                 TEM - QA - 17 - 2            32.5
#
#    Lineitem compare at price  Lineitem sku  Lineitem requires shipping  \
# 0                        NaN           NaN                        True
# 1                        NaN         361.0                        True
# 2                        NaN           NaN                        True
# 3                        NaN         361.0                        True
# 4                        NaN           NaN                        True
#
#    Lineitem taxable Lineitem fulfillment status Billing City Billing Zip  \
# 0             False                     pending    Barcelona      '08032
# 1             False                   fulfilled    Barcelona      '08021
# 2             False                   fulfilled          NaN         NaN
# 3             False                     pending    Barcelona      '08021
# 4             False                     pending          NaN         NaN
#
#   Billing Country Notes                                    Note Attributes  \
# 0              ES   NaN  Fecha de entrega: 16/04/2019\nDía de la semana...
# 1              ES   NaN  Fecha de entrega: 12/04/2019\nDía de la semana...
# 2             NaN   NaN                                                NaN
# 3              ES   NaN  Fecha de entrega: 12/04/2019\nDía de la semana...
# 4             NaN   NaN                                                NaN
#
#                 Cancelled at Payment Method Payment Reference  \
# 0                        NaN         Stripe  c2959210184748.1
# 1                        NaN         Stripe  c2946921922604.1
# 2                        NaN            NaN               NaN
# 3  2019-04-11 23:32:02 +0200         Stripe  c2946859925548.1
# 4                        NaN            NaN               NaN
#
#    Refunded Amount         Vendor            Id Tags Risk Level Source  \
# 0              0.0  Mercat a Casa  8.910100e+11  NaN        Low    web
# 1              0.0    Carns Ruano  8.869630e+11  NaN        Low    web
# 2              NaN  Mercat a Casa           NaN  NaN        NaN    NaN
# 3             45.0    Carns Ruano  8.869480e+11  NaN        Low    web
# 4              NaN  Mercat a Casa           NaN  NaN        NaN    NaN
#
#    Lineitem discount Tax 1 Name  Tax 1 Value  Tax 2 Name  Tax 2 Value  \
# 0                  0        NaN          NaN         NaN          NaN
# 1                  0        NaN          NaN         NaN          NaN
# 2                  0        NaN          NaN         NaN          NaN
# 3                  0        NaN          NaN         NaN          NaN
# 4                  0        NaN          NaN         NaN          NaN
#
#    Tax 3 Name  Tax 3 Value  Tax 4 Name  Tax 4 Value  Tax 5 Name  Tax 5 Value  \
# 0         NaN          NaN         NaN          NaN         NaN          NaN
# 1         NaN          NaN         NaN          NaN         NaN          NaN
# 2         NaN          NaN         NaN          NaN         NaN          NaN
# 3         NaN          NaN         NaN          NaN         NaN          NaN
# 4         NaN          NaN         NaN          NaN         NaN          NaN
#
#    Receipt Number
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %% [markdown]
# It seems that we have a lot of nan values and I'm not sure what the Tax N Value and Name are and seem to be empty. Let's check all Nan values compared to the total amount of data we have.

# %%
orders.shape
# Out:
# (2415, 49)

# %%
orders.isna().sum()
# Out:
# Name                              0
# Financial Status               2178
# Paid at                        2258
# Fulfillment Status             2178
# Fulfilled at                   2208
# Accepts Marketing              2178
# Currency                       2178
# Subtotal                       2178
# Shipping                       2178
# Taxes                          2178
# Total                          2178
# Discount Code                  2378
# Discount Amount                2178
# Shipping Method                2188
# Created at                        0
# Lineitem quantity                 0
# Lineitem name                     0
# Lineitem price                    0
# Lineitem compare at price      2392
# Lineitem sku                     79
# Lineitem requires shipping        0
# Lineitem taxable                  0
# Lineitem fulfillment status       0
# Billing City                   2186
# Billing Zip                    2186
# Billing Country                2185
# Notes                          2362
# Note Attributes                2195
# Cancelled at                   2386
# Payment Method                 2178
# Payment Reference              2215
# Refunded Amount                2178
# Vendor                            8
# Id                             2178
# Tags                           2411
# Risk Level                     2178
# Source                         2178
# Lineitem discount                 0
# Tax 1 Name                     2409
# Tax 1 Value                    2409
# Tax 2 Name                     2415
# Tax 2 Value                    2415
# Tax 3 Name                     2415
# Tax 3 Value                    2415
# Tax 4 Name                     2415
# Tax 4 Value                    2415
# Tax 5 Name                     2415
# Tax 5 Value                    2415
# Receipt Number                 2415
# dtype: int64

# %% [markdown]
# Ok, so we have plenty of NaNs. We'll drop all 'Tax' related values except the #1 as there is no data in them. Also 'Receipt Number' has no values so we will also drop it.

# %%
orders.drop(columns=['Tax 2 Name', 'Tax 2 Value', 'Tax 3 Name', 'Tax 3 Value', 'Tax 4 Name', 'Tax 4 Value', 'Tax 5 Name', 'Tax 5 Value', 'Receipt Number'], inplace=True)

# %% [markdown]
# Each row is a register for an order but there's no unique Id for each row. The 'Id' we have is mostly empty.
# We have 2 possible scenarios:
#
# 1) 'Id' is the order id and we only have 2415 - 2178 = 237 orders
#
# 2) All the rows are actually orders but there is no id.
#
# The most probable option is 1 but to discard option 2, we will group by 'Created at' as it is a not-null variable and if two rows are created at exactly the same time, we can assume that correspond to the same order.

# %%
orders.groupby('Created at').count().shape
# Out:
# (237, 39)

# %% [markdown]
# We have 237 different Timestamps, meaning that we actually have 237 orders, the empty data refers to specific information of the order. Actually, the 'Name' appears to be the ID of the orders.

# %%
orders.groupby('Name').count().shape
# Out:
# (237, 39)

# %%
orders['Name'].value_counts().head()
# Out:
# #1164    34
# #1171    33
# #1051    32
# #1153    30
# #1009    30
# Name: Name, dtype: int64

# %%
orders['Name'].value_counts().tail()
# Out:
# #1203    1
# #1195    1
# #1019    1
# #1220    1
# #1211    1
# Name: Name, dtype: int64

# %% [markdown]
# So we have some orders with 34 rows of information and some with just 1. Let's check the order #1164 to better understand what type of information we might find in the additional rows.

# %%
orders[orders['Name']=='#1164']
# Out:
#       Name Financial Status                    Paid at Fulfillment Status  \
# 266  #1164             paid  2019-01-15 22:58:00 +0100          fulfilled
# 267  #1164              NaN                        NaN                NaN
# 268  #1164              NaN                        NaN                NaN
# 269  #1164              NaN                        NaN                NaN
# 270  #1164              NaN                        NaN                NaN
# 271  #1164              NaN                        NaN                NaN
# 272  #1164              NaN                        NaN                NaN
# 273  #1164              NaN                        NaN                NaN
# 274  #1164              NaN                        NaN                NaN
# 275  #1164              NaN                        NaN                NaN
# 276  #1164              NaN                        NaN                NaN
# 277  #1164              NaN                        NaN                NaN
# 278  #1164              NaN                        NaN                NaN
# 279  #1164              NaN                        NaN                NaN
# 280  #1164              NaN                        NaN                NaN
# 281  #1164              NaN                        NaN                NaN
# 282  #1164              NaN                        NaN                NaN
# 283  #1164              NaN                        NaN                NaN
# 284  #1164              NaN                        NaN                NaN
# 285  #1164              NaN                        NaN                NaN
# 286  #1164              NaN                        NaN                NaN
# 287  #1164              NaN                        NaN                NaN
# 288  #1164              NaN                        NaN                NaN
# 289  #1164              NaN                        NaN                NaN
# 290  #1164              NaN                        NaN                NaN
# 291  #1164              NaN                        NaN                NaN
# 292  #1164              NaN                        NaN                NaN
# 293  #1164              NaN                        NaN                NaN
# 294  #1164              NaN                        NaN                NaN
# 295  #1164              NaN                        NaN                NaN
# 296  #1164              NaN                        NaN                NaN
# 297  #1164              NaN                        NaN                NaN
# 298  #1164              NaN                        NaN                NaN
# 299  #1164              NaN                        NaN                NaN
#
#                   Fulfilled at Accepts Marketing Currency  Subtotal  Shipping  \
# 266  2019-01-15 23:46:53 +0100               yes      EUR     105.1       0.0
# 267                        NaN               NaN      NaN       NaN       NaN
# 268                        NaN               NaN      NaN       NaN       NaN
# 269                        NaN               NaN      NaN       NaN       NaN
# 270                        NaN               NaN      NaN       NaN       NaN
# 271                        NaN               NaN      NaN       NaN       NaN
# 272                        NaN               NaN      NaN       NaN       NaN
# 273                        NaN               NaN      NaN       NaN       NaN
# 274                        NaN               NaN      NaN       NaN       NaN
# 275                        NaN               NaN      NaN       NaN       NaN
# 276                        NaN               NaN      NaN       NaN       NaN
# 277                        NaN               NaN      NaN       NaN       NaN
# 278                        NaN               NaN      NaN       NaN       NaN
# 279                        NaN               NaN      NaN       NaN       NaN
# 280                        NaN               NaN      NaN       NaN       NaN
# 281                        NaN               NaN      NaN       NaN       NaN
# 282                        NaN               NaN      NaN       NaN       NaN
# 283                        NaN               NaN      NaN       NaN       NaN
# 284                        NaN               NaN      NaN       NaN       NaN
# 285                        NaN               NaN      NaN       NaN       NaN
# 286                        NaN               NaN      NaN       NaN       NaN
# 287                        NaN               NaN      NaN       NaN       NaN
# 288                        NaN               NaN      NaN       NaN       NaN
# 289                        NaN               NaN      NaN       NaN       NaN
# 290                        NaN               NaN      NaN       NaN       NaN
# 291                        NaN               NaN      NaN       NaN       NaN
# 292                        NaN               NaN      NaN       NaN       NaN
# 293                        NaN               NaN      NaN       NaN       NaN
# 294                        NaN               NaN      NaN       NaN       NaN
# 295                        NaN               NaN      NaN       NaN       NaN
# 296                        NaN               NaN      NaN       NaN       NaN
# 297                        NaN               NaN      NaN       NaN       NaN
# 298                        NaN               NaN      NaN       NaN       NaN
# 299                        NaN               NaN      NaN       NaN       NaN
#
#      Taxes  Total Discount Code  Discount Amount Shipping Method  \
# 266    0.0  105.1           NaN              0.0  Envío gratuito
# 267    NaN    NaN           NaN              NaN             NaN
# 268    NaN    NaN           NaN              NaN             NaN
# 269    NaN    NaN           NaN              NaN             NaN
# 270    NaN    NaN           NaN              NaN             NaN
# 271    NaN    NaN           NaN              NaN             NaN
# 272    NaN    NaN           NaN              NaN             NaN
# 273    NaN    NaN           NaN              NaN             NaN
# 274    NaN    NaN           NaN              NaN             NaN
# 275    NaN    NaN           NaN              NaN             NaN
# 276    NaN    NaN           NaN              NaN             NaN
# 277    NaN    NaN           NaN              NaN             NaN
# 278    NaN    NaN           NaN              NaN             NaN
# 279    NaN    NaN           NaN              NaN             NaN
# 280    NaN    NaN           NaN              NaN             NaN
# 281    NaN    NaN           NaN              NaN             NaN
# 282    NaN    NaN           NaN              NaN             NaN
# 283    NaN    NaN           NaN              NaN             NaN
# 284    NaN    NaN           NaN              NaN             NaN
# 285    NaN    NaN           NaN              NaN             NaN
# 286    NaN    NaN           NaN              NaN             NaN
# 287    NaN    NaN           NaN              NaN             NaN
# 288    NaN    NaN           NaN              NaN             NaN
# 289    NaN    NaN           NaN              NaN             NaN
# 290    NaN    NaN           NaN              NaN             NaN
# 291    NaN    NaN           NaN              NaN             NaN
# 292    NaN    NaN           NaN              NaN             NaN
# 293    NaN    NaN           NaN              NaN             NaN
# 294    NaN    NaN           NaN              NaN             NaN
# 295    NaN    NaN           NaN              NaN             NaN
# 296    NaN    NaN           NaN              NaN             NaN
# 297    NaN    NaN           NaN              NaN             NaN
# 298    NaN    NaN           NaN              NaN             NaN
# 299    NaN    NaN           NaN              NaN             NaN
#
#                     Created at  Lineitem quantity  \
# 266  2019-01-15 22:57:57 +0100                  1
# 267  2019-01-15 22:57:57 +0100                  1
# 268  2019-01-15 22:57:57 +0100                  1
# 269  2019-01-15 22:57:57 +0100                  1
# 270  2019-01-15 22:57:57 +0100                  1
# 271  2019-01-15 22:57:57 +0100                  1
# 272  2019-01-15 22:57:57 +0100                  1
# 273  2019-01-15 22:57:57 +0100                  1
# 274  2019-01-15 22:57:57 +0100                  1
# 275  2019-01-15 22:57:57 +0100                  1
# 276  2019-01-15 22:57:57 +0100                  1
# 277  2019-01-15 22:57:57 +0100                  1
# 278  2019-01-15 22:57:57 +0100                  1
# 279  2019-01-15 22:57:57 +0100                  1
# 280  2019-01-15 22:57:57 +0100                  1
# 281  2019-01-15 22:57:57 +0100                  1
# 282  2019-01-15 22:57:57 +0100                  1
# 283  2019-01-15 22:57:57 +0100                  1
# 284  2019-01-15 22:57:57 +0100                  1
# 285  2019-01-15 22:57:57 +0100                  1
# 286  2019-01-15 22:57:57 +0100                  1
# 287  2019-01-15 22:57:57 +0100                  1
# 288  2019-01-15 22:57:57 +0100                  1
# 289  2019-01-15 22:57:57 +0100                  1
# 290  2019-01-15 22:57:57 +0100                  1
# 291  2019-01-15 22:57:57 +0100                  1
# 292  2019-01-15 22:57:57 +0100                  1
# 293  2019-01-15 22:57:57 +0100                  1
# 294  2019-01-15 22:57:57 +0100                  1
# 295  2019-01-15 22:57:57 +0100                  1
# 296  2019-01-15 22:57:57 +0100                  1
# 297  2019-01-15 22:57:57 +0100                  1
# 298  2019-01-15 22:57:57 +0100                  1
# 299  2019-01-15 22:57:57 +0100                  1
#
#                                          Lineitem name  Lineitem price  \
# 266                      Jamón serrano cebo - 150 grs.            8.25
# 267                             Jamón dulce - 150 grs.            2.70
# 268                        Tomate Monterosa - 500 grs.            1.95
# 269                          Tomate de untar (300 grs)            1.80
# 270                          Puerro - 1 Kg. (2/3 uds.)            2.80
# 271               Pimientos Rojo - 500 grs. (1/2 uds.)            1.45
# 272                            Patata Kennebec - 1 Kg.            1.40
# 273                       Judía Perona fina - 500 grs.            3.90
# 274                                Jengibre - 100 grs.            0.50
# 275                         Espinacas - Bolsa 300 grs.            2.00
# 276                   Cebolla Morada - 1 Kg. (3/4 uds)            1.50
# 277                  Cebolla Figueras - 1 Kg. (4 uds.)            2.50
# 278                               Calabacín - 500 grs.            1.45
# 279                                 Brócoli - 1 unidad            2.30
# 280                                   Comté - 200 grs.            5.00
# 281                   Queso rallado emmental - 1 bolsa            1.30
# 282                      Boquerones limpios - 350 grs.            4.10
# 283                        Almejas gallegas - 200 grs.            5.40
# 284                   Atún Rojo de la Costa - 300 grs.           14.70
# 285                          Almendra Cruda - 250 grs.            4.00
# 286                      Ciruelas sin hueso - 250 grs.            2.10
# 287           Nueces California sin cáscara - 250 grs.            4.25
# 288              Plátano Canarias Verde - 3/4 unidades            1.95
# 289                       Pera Conference - 4 unidades            1.60
# 290                              Naranjas zumo - 2 kg.            2.90
# 291                        Manzana Golden - 4 unidades            2.00
# 292                               Mandarina - 500 grs.            1.45
# 293                                 Granada - 1 unidad            1.00
# 294              Pechuga de pollo fileteada - 350 grs.            3.15
# 295                       Muslitos de Pollo - 500 grs.            3.30
# 296                     Huevos ecológicos - 6 unidades            2.60
# 297  Hamburguesas Gourmet de pollo con cebolla - 2 ...            3.20
# 298                   Croquetas de Rustit - 6 unidades            3.75
# 299           Pasta fresca lisa Tagliatelle - 300 grs.            2.85
#
#      Lineitem compare at price  Lineitem sku  Lineitem requires shipping  \
# 266                        NaN         398.0                        True
# 267                        NaN         395.0                        True
# 268                        NaN         351.0                        True
# 269                        NaN         354.0                        True
# 270                        NaN         333.0                        True
# 271                        NaN         158.0                        True
# 272                        NaN         155.0                        True
# 273                        NaN         149.0                        True
# 274                        NaN         342.0                        True
# 275                        NaN         148.0                        True
# 276                        NaN         321.0                        True
# 277                        NaN         320.0                        True
# 278                        NaN         141.0                        True
# 279                        NaN         140.0                        True
# 280                        NaN         466.0                        True
# 281                        NaN         406.0                        True
# 282                        NaN         291.0                        True
# 283                        NaN         297.0                        True
# 284                        NaN         289.0                        True
# 285                        NaN          76.0                        True
# 286                        NaN          45.0                        True
# 287                        NaN          83.0                        True
# 288                        NaN         132.0                        True
# 289                        NaN         129.0                        True
# 290                        0.0         308.0                        True
# 291                        NaN         124.0                        True
# 292                        NaN         304.0                        True
# 293                        NaN         302.0                        True
# 294                        NaN          12.0                        True
# 295                        NaN         205.0                        True
# 296                        NaN          32.0                        True
# 297                        NaN          21.0                        True
# 298                        NaN          22.0                        True
# 299                        NaN         213.0                        True
#
#      Lineitem taxable Lineitem fulfillment status Billing City Billing Zip  \
# 266             False                   fulfilled    Barcelona      '08006
# 267             False                   fulfilled          NaN         NaN
# 268             False                   fulfilled          NaN         NaN
# 269             False                   fulfilled          NaN         NaN
# 270             False                   fulfilled          NaN         NaN
# 271             False                   fulfilled          NaN         NaN
# 272             False                   fulfilled          NaN         NaN
# 273             False                   fulfilled          NaN         NaN
# 274             False                   fulfilled          NaN         NaN
# 275             False                   fulfilled          NaN         NaN
# 276             False                   fulfilled          NaN         NaN
# 277             False                   fulfilled          NaN         NaN
# 278             False                   fulfilled          NaN         NaN
# 279             False                   fulfilled          NaN         NaN
# 280             False                   fulfilled          NaN         NaN
# 281             False                   fulfilled          NaN         NaN
# 282             False                   fulfilled          NaN         NaN
# 283             False                   fulfilled          NaN         NaN
# 284             False                   fulfilled          NaN         NaN
# 285             False                   fulfilled          NaN         NaN
# 286             False                   fulfilled          NaN         NaN
# 287             False                   fulfilled          NaN         NaN
# 288             False                   fulfilled          NaN         NaN
# 289             False                   fulfilled          NaN         NaN
# 290             False                   fulfilled          NaN         NaN
# 291             False                   fulfilled          NaN         NaN
# 292             False                   fulfilled          NaN         NaN
# 293             False                   fulfilled          NaN         NaN
# 294             False                   fulfilled          NaN         NaN
# 295             False                   fulfilled          NaN         NaN
# 296             False                   fulfilled          NaN         NaN
# 297             False                   fulfilled          NaN         NaN
# 298             False                   fulfilled          NaN         NaN
# 299             False                   fulfilled          NaN         NaN
#
#     Billing Country Notes                                    Note Attributes  \
# 266              ES   NaN  streamthing_delivery_date: January 16th, 2019\...
# 267             NaN   NaN                                                NaN
# 268             NaN   NaN                                                NaN
# 269             NaN   NaN                                                NaN
# 270             NaN   NaN                                                NaN
# 271             NaN   NaN                                                NaN
# 272             NaN   NaN                                                NaN
# 273             NaN   NaN                                                NaN
# 274             NaN   NaN                                                NaN
# 275             NaN   NaN                                                NaN
# 276             NaN   NaN                                                NaN
# 277             NaN   NaN                                                NaN
# 278             NaN   NaN                                                NaN
# 279             NaN   NaN                                                NaN
# 280             NaN   NaN                                                NaN
# 281             NaN   NaN                                                NaN
# 282             NaN   NaN                                                NaN
# 283             NaN   NaN                                                NaN
# 284             NaN   NaN                                                NaN
# 285             NaN   NaN                                                NaN
# 286             NaN   NaN                                                NaN
# 287             NaN   NaN                                                NaN
# 288             NaN   NaN                                                NaN
# 289             NaN   NaN                                                NaN
# 290             NaN   NaN                                                NaN
# 291             NaN   NaN                                                NaN
# 292             NaN   NaN                                                NaN
# 293             NaN   NaN                                                NaN
# 294             NaN   NaN                                                NaN
# 295             NaN   NaN                                                NaN
# 296             NaN   NaN                                                NaN
# 297             NaN   NaN                                                NaN
# 298             NaN   NaN                                                NaN
# 299             NaN   NaN                                                NaN
#
#     Cancelled at Payment Method Payment Reference  Refunded Amount  \
# 266          NaN         Stripe  c2584919212076.1              0.0
# 267          NaN            NaN               NaN              NaN
# 268          NaN            NaN               NaN              NaN
# 269          NaN            NaN               NaN              NaN
# 270          NaN            NaN               NaN              NaN
# 271          NaN            NaN               NaN              NaN
# 272          NaN            NaN               NaN              NaN
# 273          NaN            NaN               NaN              NaN
# 274          NaN            NaN               NaN              NaN
# 275          NaN            NaN               NaN              NaN
# 276          NaN            NaN               NaN              NaN
# 277          NaN            NaN               NaN              NaN
# 278          NaN            NaN               NaN              NaN
# 279          NaN            NaN               NaN              NaN
# 280          NaN            NaN               NaN              NaN
# 281          NaN            NaN               NaN              NaN
# 282          NaN            NaN               NaN              NaN
# 283          NaN            NaN               NaN              NaN
# 284          NaN            NaN               NaN              NaN
# 285          NaN            NaN               NaN              NaN
# 286          NaN            NaN               NaN              NaN
# 287          NaN            NaN               NaN              NaN
# 288          NaN            NaN               NaN              NaN
# 289          NaN            NaN               NaN              NaN
# 290          NaN            NaN               NaN              NaN
# 291          NaN            NaN               NaN              NaN
# 292          NaN            NaN               NaN              NaN
# 293          NaN            NaN               NaN              NaN
# 294          NaN            NaN               NaN              NaN
# 295          NaN            NaN               NaN              NaN
# 296          NaN            NaN               NaN              NaN
# 297          NaN            NaN               NaN              NaN
# 298          NaN            NaN               NaN              NaN
# 299          NaN            NaN               NaN              NaN
#
#                         Vendor            Id Tags Risk Level Source  \
# 266   Xarcuteria Alonso Andrés  7.858760e+11  NaN        Low    web
# 267   Xarcuteria Alonso Andrés           NaN  NaN        NaN    NaN
# 268  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 269  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 270  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 271  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 272  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 273  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 274  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 275  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 276  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 277  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 278  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 279  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 280   Xarcuteria Alonso Andrés           NaN  NaN        NaN    NaN
# 281   Xarcuteria Alonso Andrés           NaN  NaN        NaN    NaN
# 282       Peixateria La Ribera           NaN  NaN        NaN    NaN
# 283       Peixateria La Ribera           NaN  NaN        NaN    NaN
# 284       Peixateria La Ribera           NaN  NaN        NaN    NaN
# 285        Llegums Porta Novau           NaN  NaN        NaN    NaN
# 286        Llegums Porta Novau           NaN  NaN        NaN    NaN
# 287        Llegums Porta Novau           NaN  NaN        NaN    NaN
# 288  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 289  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 290  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 291  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 292  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 293  Fruites i Verdures Rovira           NaN  NaN        NaN    NaN
# 294                   El Pagés           NaN  NaN        NaN    NaN
# 295                   El Pagés           NaN  NaN        NaN    NaN
# 296                   El Pagés           NaN  NaN        NaN    NaN
# 297                   El Pagés           NaN  NaN        NaN    NaN
# 298                   El Pagés           NaN  NaN        NaN    NaN
# 299        Llegums Porta Novau           NaN  NaN        NaN    NaN
#
#      Lineitem discount Tax 1 Name  Tax 1 Value
# 266                  0        NaN          NaN
# 267                  0        NaN          NaN
# 268                  0        NaN          NaN
# 269                  0        NaN          NaN
# 270                  0        NaN          NaN
# 271                  0        NaN          NaN
# 272                  0        NaN          NaN
# 273                  0        NaN          NaN
# 274                  0        NaN          NaN
# 275                  0        NaN          NaN
# 276                  0        NaN          NaN
# 277                  0        NaN          NaN
# 278                  0        NaN          NaN
# 279                  0        NaN          NaN
# 280                  0        NaN          NaN
# 281                  0        NaN          NaN
# 282                  0        NaN          NaN
# 283                  0        NaN          NaN
# 284                  0        NaN          NaN
# 285                  0        NaN          NaN
# 286                  0        NaN          NaN
# 287                  0        NaN          NaN
# 288                  0        NaN          NaN
# 289                  0        NaN          NaN
# 290                  0        NaN          NaN
# 291                  0        NaN          NaN
# 292                  0        NaN          NaN
# 293                  0        NaN          NaN
# 294                  0        NaN          NaN
# 295                  0        NaN          NaN
# 296                  0        NaN          NaN
# 297                  0        NaN          NaN
# 298                  0        NaN          NaN
# 299                  0        NaN          NaN

# %% [markdown]
# We can see that there is unique information for the first row. This would be the general order information, which includes:
#
#     order_specific = ['Name', 'Financial Status', 'Paid at', 'Fulfillment Status', 'Fulfilled at', 'Accepts Marketing', 'Currency', 'Subtotal', 'Shipping', 'Taxes', 'Total', 'Discount Amount', 'Shipping Method', 'Billing City', 'Billing Zip', 'Billing Country', 'Note Attributes', 'Payment Method', 'Payment Reference', 'Refunded Amount', 'Id', 'Risk Level', 'Source']
#
# Other variables are clearly item-specific:
#
#     item_specific = ['Lineitem quantity', 'Lineitem name', 'Lineitem price', 'Lineitem sku', 'Lineitem requires shipping', 'Lineitem taxable', 'Lineitem fulfillment status']
#
#
# Some variables could be either also order-specific or item-specific information but need to be confirmed as here they contain NaN values for all the rows.
#
#     uncertain_order = ['Discount Code','Notes', 'Cancelled at', 'Tags', 'Tax 1 Name', 'Tax 1 Value']
#     uncertain_item = ['Lineitem compare at price']
#
# We will now split the DataFrame as follows:
# * order_specific information
# * item_specific information
#
# To do that we need:
#
# 1) Classify the uncertain variables
#
# 2) Reference both tables with some sort of Order Id

# %% [markdown]
# ### Classify the uncertain variables

# %%
orders[['Discount Code','Notes', 'Cancelled at', 'Tags', 'Tax 1 Name', 'Tax 1 Value']].notna().sum()
# Out:
# Discount Code    37
# Notes            53
# Cancelled at     29
# Tags              4
# Tax 1 Name        6
# Tax 1 Value       6
# dtype: int64

# %%
orders[orders['Discount Code'].notna()]['Name'].value_counts().head()
# Out:
# #1126    1
# #1186    1
# #1075    1
# #1189    1
# #1204    1
# Name: Name, dtype: int64

# %% [markdown]
# We can see that 'Discount Code' is unique per order. We'll do the same for the rest of variables

# %%
orders[orders['Notes'].notna()]['Name'].value_counts().head()
# Out:
# #1021    1
# #1182    1
# #1034    1
# #1042    1
# #1184    1
# Name: Name, dtype: int64

# %%
orders[orders['Cancelled at'].notna()]['Name'].value_counts().head()
# Out:
# #1015    1
# #1056    1
# #1175    1
# #1173    1
# #1183    1
# Name: Name, dtype: int64

# %%
orders[orders['Tags'].notna()]['Name'].value_counts().head()
# Out:
# #1233    1
# #1234    1
# #1232    1
# #1235    1
# Name: Name, dtype: int64

# %%
orders[orders['Tax 1 Name'].notna()]['Name'].value_counts().head()
# Out:
# #1075    1
# #1074    1
# #1176    1
# #1199    1
# #1174    1
# Name: Name, dtype: int64

# %%
orders[orders['Tax 1 Value'].notna()]['Name'].value_counts().head()
# Out:
# #1075    1
# #1074    1
# #1176    1
# #1199    1
# #1174    1
# Name: Name, dtype: int64

# %%
orders[orders['Lineitem compare at price'].notna()]['Name'].value_counts().head()
# Out:
# #1152    2
# #1109    2
# #1134    2
# #1165    2
# #1111    1
# Name: Name, dtype: int64

# %% [markdown]
# All the uncertain variables are unique to each order or item as we suspected (so uncertain lists are now certain) but only fulfilled for few orders/items. We will put them in the specific DataFrames and then decide later what to do with it. The updated list of variables per dataframe is the following:
#
#     order_specific = ['Name', 'Financial Status', 'Paid at', 'Fulfillment Status', 'Fulfilled at', 'Accepts Marketing', 'Currency', 'Subtotal', 'Shipping', 'Taxes', 'Total', 'Discount Amount', 'Shipping Method', 'Billing City', 'Billing Zip', 'Billing Country', 'Note Attributes', 'Payment Method', 'Payment Reference', 'Refunded Amount', 'Id', 'Risk Level', 'Source', 'Discount Code','Notes', 'Cancelled at', 'Tags', 'Tax 1 Name', 'Tax 1 Value']
#
#     item_specific = ['Lineitem quantity', 'Lineitem name', 'Lineitem price', 'Lineitem sku', 'Lineitem requires shipping', 'Lineitem taxable', 'Lineitem fulfillment status', 'Lineitem compare at price']

# %% [markdown]
# ## Splitting the dataframe

# %% [markdown]
# To ease the understanding of the information we will split our dataframe in 2. The first will be order-specific and the second item-specific. This will help us to better structure the database, and clean each DF separately with a better undestanding of each variable.

# %%
cols_order = ['Name', 'Financial Status', 'Paid at', 'Fulfillment Status', 'Fulfilled at', 'Accepts Marketing', 'Currency', 'Subtotal', 'Shipping', 'Taxes', 'Total', 'Discount Amount', 'Shipping Method', 'Billing City', 'Billing Zip', 'Billing Country', 'Note Attributes', 'Payment Method', 'Payment Reference', 'Refunded Amount', 'Id', 'Risk Level', 'Source', 'Discount Code','Notes', 'Cancelled at', 'Tags', 'Tax 1 Name', 'Tax 1 Value']
order_specific = orders[cols_order]

#note that we are including 'name' and 'id' to the item-specific dataframe so that this information is traceable to the specific order.
cols_item = ['Name', 'Id', 'Lineitem quantity', 'Lineitem name', 'Lineitem price', 'Lineitem sku', 'Lineitem requires shipping', 'Lineitem taxable', 'Lineitem fulfillment status', 'Lineitem compare at price']
item_specific = orders[cols_item]

# %% [markdown]
# ## Cleaning order-specific data

# %%
order_specific.head()
# Out:
#     Name Financial Status                    Paid at Fulfillment Status  \
# 0  #1244             paid  2019-04-15 09:51:49 +0200        unfulfilled
# 1  #1243             paid  2019-04-11 23:35:23 +0200          fulfilled
# 2  #1243              NaN                        NaN                NaN
# 3  #1242         refunded  2019-04-11 23:21:35 +0200        unfulfilled
# 4  #1242              NaN                        NaN                NaN
#
#                 Fulfilled at Accepts Marketing Currency  Subtotal  Shipping  \
# 0                        NaN               yes      EUR      45.0       4.9
# 1  2019-04-11 23:43:20 +0200               yes      EUR      40.1       4.9
# 2                        NaN               NaN      NaN       NaN       NaN
# 3                        NaN               yes      EUR      40.1       4.9
# 4                        NaN               NaN      NaN       NaN       NaN
#
#    Taxes  Total  Discount Amount Shipping Method Billing City Billing Zip  \
# 0    0.0   49.9              0.0  Envío estándar    Barcelona      '08032
# 1    0.0   45.0              0.0  Envío estándar    Barcelona      '08021
# 2    NaN    NaN              NaN             NaN          NaN         NaN
# 3    0.0   45.0              0.0  Envío estándar    Barcelona      '08021
# 4    NaN    NaN              NaN             NaN          NaN         NaN
#
#   Billing Country                                    Note Attributes  \
# 0              ES  Fecha de entrega: 16/04/2019\nDía de la semana...
# 1              ES  Fecha de entrega: 12/04/2019\nDía de la semana...
# 2             NaN                                                NaN
# 3              ES  Fecha de entrega: 12/04/2019\nDía de la semana...
# 4             NaN                                                NaN
#
#   Payment Method Payment Reference  Refunded Amount            Id Risk Level  \
# 0         Stripe  c2959210184748.1              0.0  8.910100e+11        Low
# 1         Stripe  c2946921922604.1              0.0  8.869630e+11        Low
# 2            NaN               NaN              NaN           NaN        NaN
# 3         Stripe  c2946859925548.1             45.0  8.869480e+11        Low
# 4            NaN               NaN              NaN           NaN        NaN
#
#   Source Discount Code Notes               Cancelled at Tags Tax 1 Name  \
# 0    web           NaN   NaN                        NaN  NaN        NaN
# 1    web           NaN   NaN                        NaN  NaN        NaN
# 2    NaN           NaN   NaN                        NaN  NaN        NaN
# 3    web           NaN   NaN  2019-04-11 23:32:02 +0200  NaN        NaN
# 4    NaN           NaN   NaN                        NaN  NaN        NaN
#
#    Tax 1 Value
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# We need to keep only the first row of each order, the rest contains only NaN values.

# %%
order_specific_clean = pd.DataFrame()
for order in list(order_specific['Name'].unique()):
    order_specific_clean = order_specific_clean.append(order_specific[order_specific['Name']==order].head(1))

# %%
order_specific_clean.isna().sum()
# Out:
# Name                    0
# Financial Status        0
# Paid at                80
# Fulfillment Status      0
# Fulfilled at           30
# Accepts Marketing       0
# Currency                0
# Subtotal                0
# Shipping                0
# Taxes                   0
# Total                   0
# Discount Amount         0
# Shipping Method        10
# Billing City            8
# Billing Zip             8
# Billing Country         7
# Note Attributes        17
# Payment Method          0
# Payment Reference      37
# Refunded Amount         0
# Id                      0
# Risk Level              0
# Source                  0
# Discount Code         200
# Notes                 184
# Cancelled at          208
# Tags                  233
# Tax 1 Name            231
# Tax 1 Value           231
# dtype: int64

# %% [markdown]
# We can see that:
# * 80 orders were not registered as paid
# * 30 orders were not fulfilled
# * 10 orders do not have shipping method
# * 8 orders do not have Billing city nor Billing Zip
# * 7 orders do not have Billing country
# * 17 orders do not have Note Attributes
# * 37 orders do not have a payment reference
# * 200 orders do not have a discout code
# * 184 orders do not have notes
# * 208 orders were not cancelled
# * 233 orders do not have tags
# * 231 orders do not have tax information
#
# We will now analyse each of the variables with NaN values to correct this issue.

# %% [markdown]
# ### Solving NaN values

# %% [markdown]
# #### Binary encoding
